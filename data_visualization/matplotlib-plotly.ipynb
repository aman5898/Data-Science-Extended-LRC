# %% [markdown]
# <a href="https://colab.research.google.com/github/aman5898/Data-Science-Extended-LRC/blob/main/data_visualization/matplotlib-plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.express as px

# %%
df = px.data.iris()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
df
# Out:
#      sepal_length  sepal_width  ...    species  species_id
# 0             5.1          3.5  ...     setosa           1
# 1             4.9          3.0  ...     setosa           1
# 2             4.7          3.2  ...     setosa           1
# 3             4.6          3.1  ...     setosa           1
# 4             5.0          3.6  ...     setosa           1
# ..            ...          ...  ...        ...         ...
# 145           6.7          3.0  ...  virginica           3
# 146           6.3          2.5  ...  virginica           3
# 147           6.5          3.0  ...  virginica           3
# 148           6.2          3.4  ...  virginica           3
# 149           5.9          3.0  ...  virginica           3
#
# [150 rows x 6 columns]

# %%
df[df['species_id'] == 1].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width  species_id
# sepal_length      1.000000     0.746780      0.263874     0.279092         NaN
# sepal_width       0.746780     1.000000      0.176695     0.279973         NaN
# petal_length      0.263874     0.176695      1.000000     0.306308         NaN
# petal_width       0.279092     0.279973      0.306308     1.000000         NaN
# species_id             NaN          NaN           NaN          NaN         NaN

# %%
df[df['species_id'] == 2].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width  species_id
# sepal_length      1.000000     0.525911      0.754049     0.546461         NaN
# sepal_width       0.525911     1.000000      0.560522     0.663999         NaN
# petal_length      0.754049     0.560522      1.000000     0.786668         NaN
# petal_width       0.546461     0.663999      0.786668     1.000000         NaN
# species_id             NaN          NaN           NaN          NaN         NaN

# %%
df[df['species_id'] == 3].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width  species_id
# sepal_length      1.000000     0.457228      0.864225     0.281108         NaN
# sepal_width       0.457228     1.000000      0.401045     0.537728         NaN
# petal_length      0.864225     0.401045      1.000000     0.322108         NaN
# petal_width       0.281108     0.537728      0.322108     1.000000         NaN
# species_id             NaN          NaN           NaN          NaN         NaN

# %%
import matplotlib.pyplot as plt

species1 = df[df['species_id'] == 1]
species2 = df[df['species_id'] == 2]
species3 = df[df['species_id'] == 3]



plt.scatter(species1['petal_length'], species1['petal_width'], label='setosa')
plt.scatter(species2['petal_length'], species2['petal_width'], label='Versicolor')
plt.scatter(species3['petal_length'], species3['petal_width'], label='virginica')

plt.legend()
plt.show()

# %%
df
# Out:
#      sepal_length  sepal_width  ...    species  species_id
# 0             5.1          3.5  ...     setosa           1
# 1             4.9          3.0  ...     setosa           1
# 2             4.7          3.2  ...     setosa           1
# 3             4.6          3.1  ...     setosa           1
# 4             5.0          3.6  ...     setosa           1
# ..            ...          ...  ...        ...         ...
# 145           6.7          3.0  ...  virginica           3
# 146           6.3          2.5  ...  virginica           3
# 147           6.5          3.0  ...  virginica           3
# 148           6.2          3.4  ...  virginica           3
# 149           5.9          3.0  ...  virginica           3
#
# [150 rows x 6 columns]

# %%
fig = px.scatter_3d(df, x = 'petal_length', y = 'petal_width', z = 'sepal_length', color= 'species')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c707c878-cb30-4197-9650-620b95e24bca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c707c878-cb30-4197-9650-620b95e24bca")) {
#                     Plotly.newPlot(
#                         'c707c878-cb30-4197-9650-620b95e24bca',
# ...

# %%
import matplotlib.pyplot as plt

plt.plot([2, 6, 3], [4, 8, 2])
plt.show()

# %% [markdown]
# Marker

# %%
plt.plot([2, 6, 3], [4, 8, 2], marker = 'o', linestyle='-.')
plt.show()

# %%
plt.plot([2, 6, 3], [4, 8, 2], marker = 'o', ms=30, mfc = 'r', mec='g', linestyle='-.')
plt.show()

# %%
plt.plot([2, 6, 3], [4, 8, 2], linestyle='-.', linewidth = 10)
plt.show()

# %%
plt.plot([2, 6, 3], [4, 8, 2], '--og')
plt.show()

# %%
plt.plot([2, 6, 3])

# %%
import numpy as np

x = np.arange(2, 20)

plt.plot(x, x**2, marker='D', label='x^2', linestyle='')
plt.plot(x, x**2.3, marker='o', label='x^2.3',linestyle='')
plt.plot(x, x**2.5, marker='^', label='x^2.5',linestyle='')

plt.grid()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('^a')
plt.legend()

# %% [markdown]
# #Scatter
#
#
#
# 1.   size : `s`
# 2.   alpha: opacity

# %%
plt.scatter(x, x*x)

# %%
plt.scatter([4,4,7,7], [2,3,6,7], s=[1800, 1900, 800, 2000], color = ['r', 'b', 'g', 'y'], alpha = 0.5)

# %% [markdown]
# BarChart

# %%
plt.bar(['Jan', 'Feb', 'Mar'], [10, 20, 100], color = ['red', 'g', 'y'], width=[4, 2, 0.1])

plt.xlabel('Month')
plt.ylabel('Cases')
# Out:
# Text(0, 0.5, 'Cases')

# %%
plt.barh(['Jan', 'Feb', 'Mar'], [10, 20, 100], color = ['red', 'g', 'y'], height=[4, 2, 0.1])

plt.xlabel('Cases')
plt.ylabel('Month')
# Out:
# Text(0, 0.5, 'Month')

# %%
x = np.random.randn(3000)

plt.hist(x, bins = 1000)
plt.show()

# %%
x.mean(), x.std()
# Out:
# (0.018704218701066977, 1.0009358270082611)

# %% [markdown]
# Pi Chart

# %%
plt.pie([8, 7, 2, 4, 2,6, 2], labels = ['N', 'O', 'co2', 'co', 'co3', 'o3', 'others'], explode = [0.1,0.2,0.3,0.2,0.1,0.1, 0.5], shadow = True, startangle = 180)
# plt.legend()
plt.show()

# %% [markdown]
# # SubPlot
#
# figsize = (inches, inches)

# %%
plt.figure(figsize=(9, 9))

plt.subplot(2, 2, 1)
plt.pie([8, 7, 2, 4, 2,6, 2], labels = ['N', 'O', 'co2', 'co', 'co3', 'o3', 'others'], explode = [0.1,0.2,0.3,0.2,0.1,0.1, 0.5], shadow = True, startangle = 180)

plt.subplot(2, 2, 2)
plt.barh(['Jan', 'Feb', 'Mar'], [10, 20, 100], color = ['red', 'g', 'y'], height=[4, 2, 0.1])


plt.subplot(2, 2, 3)
plt.scatter([4,4,7,7], [2,3,6,7], s=[1800, 1900, 800, 2000], color = 'r', alpha = 0.5)

plt.subplot(2,2, 2)
plt.xlabel('Cases')
plt.ylabel('Month')

# plt.subplot(2,2,4)

# plt.subplot(2,1, 1)
# plt.plot([1,2,3], [7,8,8])
# plt.subplot(2,1, 2)
# plt.plot([1,2,3], [1,2,3])



plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning:
#
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# #Python Plotly
#
# Plotly Library is an open-source library that can be used for data visualization and understanding data simply and easily. Plotly supports various types of plots like line charts, scatter plots, histograms, cox plots, etc. So you all must be wondering why Plotly over other visualization tools or libraries? Here’s the answer –
#
# *   Plotly has hover tool capabilities that allow us to detect any
# outliers or anomalies in a large number of data points.
# *   It is visually attractive that can be accepted by a wide range of audiences.
# *   It allows us for the endless customization of our graphs that makes our plot more meaningful and understandable for others.

# %%
import plotly.express as px

# %%
fig = px.line(x=[1,2,3], y = [6,4,8])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fe955b98-63d8-4cbf-b2ce-3b9862e43d85" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fe955b98-63d8-4cbf-b2ce-3b9862e43d85")) {
#                     Plotly.newPlot(
#                         'fe955b98-63d8-4cbf-b2ce-3b9862e43d85',
# ...

# %%
fig = px.line_3d(x=[1,2,3], y = [6,4,8], z=[7,8,9])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dd368dc5-b3a3-4992-a61a-7dab72b2521f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dd368dc5-b3a3-4992-a61a-7dab72b2521f")) {
#                     Plotly.newPlot(
#                         'dd368dc5-b3a3-4992-a61a-7dab72b2521f',
# ...

# %% [markdown]
# #Bar Chart

# %%
df = px.data.iris()

fig = px.bar(df, x='sepal_length', y='sepal_width')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b508d0d3-8fcc-40a7-a7ab-5809f3aba02c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b508d0d3-8fcc-40a7-a7ab-5809f3aba02c")) {
#                     Plotly.newPlot(
#                         'b508d0d3-8fcc-40a7-a7ab-5809f3aba02c',
# ...

# %% [markdown]
# #Histograms

# %%
px.histogram(df, x='petal_length', y='petal_width')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="45b2913b-c450-471d-af2d-fec6cdf88e23" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("45b2913b-c450-471d-af2d-fec6cdf88e23")) {
#                     Plotly.newPlot(
#                         '45b2913b-c450-471d-af2d-fec6cdf88e23',
# ...

# %% [markdown]
# #Scatter Plot

# %%
px.scatter(df, x = 'petal_length', y = 'petal_width', color = 'species', size='sepal_length')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2ae5db3f-e0ec-4404-8dba-b2b0b1898b4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2ae5db3f-e0ec-4404-8dba-b2b0b1898b4d")) {
#                     Plotly.newPlot(
#                         '2ae5db3f-e0ec-4404-8dba-b2b0b1898b4d',
# ...

# %%
px.scatter(df, x = 'species', y = 'petal_width', color = 'species', size='sepal_length')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c0284e1c-63a5-4e38-a91c-cc01ddf23705" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c0284e1c-63a5-4e38-a91c-cc01ddf23705")) {
#                     Plotly.newPlot(
#                         'c0284e1c-63a5-4e38-a91c-cc01ddf23705',
# ...

# %%
fig = px.scatter_3d(df, x = 'petal_length', y = 'petal_width', color = 'species', size='sepal_length', z='sepal_width')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="90503af1-3cad-4c98-90eb-3a8978a776bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("90503af1-3cad-4c98-90eb-3a8978a776bc")) {
#                     Plotly.newPlot(
#                         '90503af1-3cad-4c98-90eb-3a8978a776bc',
# ...

# %% [markdown]
# #outlier

# %%
x = np.arange(20)
y = x*3 + np.random.randn(20)*5

x = np.append(x, 6)
y = np.append(y, 60)

plt.scatter(x, y)

# %% [markdown]
# #Box Plot

# %%
df = px.data.tips()
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = px.box(df, x='day', y = 'tip')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b2688b3e-421e-48c2-9992-efde4a60404d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b2688b3e-421e-48c2-9992-efde4a60404d")) {
#                     Plotly.newPlot(
#                         'b2688b3e-421e-48c2-9992-efde4a60404d',
# ...

# %%
df[(df['day'] == 'Thur') & (df['tip'] > 5.17)]

# df.drop(columns = [], index=[])
# Out:
#      total_bill   tip   sex smoker   day   time  size
# 88        24.71  5.85  Male     No  Thur  Lunch     2
# 141       34.30  6.70  Male     No  Thur  Lunch     6

# %% [markdown]
# #Violin plots

# %%
fig = px.violin(df, x="day", y="total_bill")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="44b5b802-8b94-4371-92ad-59dd2fe5cd85" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("44b5b802-8b94-4371-92ad-59dd2fe5cd85")) {
#                     Plotly.newPlot(
#                         '44b5b802-8b94-4371-92ad-59dd2fe5cd85',
# ...

# %% [markdown]
# #Pie Charts

# %%
fig = px.pie(df, names='day', values='tip')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8eb62261-bdf5-403d-b1e9-350a0f886340" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8eb62261-bdf5-403d-b1e9-350a0f886340")) {
#                     Plotly.newPlot(
#                         '8eb62261-bdf5-403d-b1e9-350a0f886340',
# ...

# %%
import plotly.graph_objects as go

# %%
import plotly.graph_objects as go
import numpy as np

X, Y, Z = np.mgrid[-5:5:40j, -5:5:40j, 0:5:20j]

values = X * X * 0.5 + Y * Y + Z * Z * 2

fig = go.Figure(data=go.Isosurface(
    x=X.flatten(),
    y=Y.flatten(),
    z=Z.flatten(),
    value=values.flatten(),
    isomin=30,
    isomax=50,
    surface=dict(count=3, fill=0.7, pattern='odd'),
    ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bf7f6dd5-6bf9-44bf-8ebd-e3da78e51d90" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bf7f6dd5-6bf9-44bf-8ebd-e3da78e51d90")) {
#                     Plotly.newPlot(
#                         'bf7f6dd5-6bf9-44bf-8ebd-e3da78e51d90',
# ...
